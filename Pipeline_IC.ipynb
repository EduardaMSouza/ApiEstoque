# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardaMSouza/ApiEstoque/blob/main/Pipeline_IC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
import zipfile
with zipfile.ZipFile([file for file in os.listdir('/content/') if file.endswith('.zip')][0],"r") as zip_ref:
    zip_ref.extractall("IC_codes")

# %%
if os.environ.get("TOKENIZE_PIP_ALREADY_RUN") != "1":
  # !pip install h5py
  # !pip install typing-extensions
  # !pip install wheel

os.environ["TOKENIZE_PIP_ALREADY_RUN"] = "1"
os.environ["TO_BE_TOKENIZED_DIR"] = "/content/"
os.environ["TOKENIZED_XML_DIR"] = "/content/tokenized_files/"
# %run /content/IC_codes/tokenize_xml.py
# Out:
# Pip commands were already executed!
#   File "<string>", line unknown
# ParseError: mismatched tag: line 13, column 61

# %%
os.environ["PREDICTED_XML_DIR"] = "/content/predicted_files/"
os.environ["DECISION_TREE_DIR"] = "IC_codes/"
os.environ["RESERVED_WORDS"] = 'Informar;Inserir'
# %run /content/IC_codes/predicting_type_with_trained_decision_tree.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /content/IC_codes/predicting_type_with_trained_decision_tree.py in <module>
#     203
#     204 #@title Run ***predict()***
# --> 205 predicted_xmls = predict(tree_file_folder, reserved_words, tokenized_folder, save_folder)
#
# /content/IC_codes/predicting_type_with_trained_decision_tree.py in predict(tree_file_folder, reserved_words, tokenized_folder, save_folder)
#     150 def predict(tree_file_folder, reserved_words, tokenized_folder, save_folder):
#     151   #Gets phrases
# --> 152   xml_files = get_xml_files(tokenized_folder)
#     153   #Predicts and get dataframe for each xml file
#     154   i=0
#
# /content/IC_codes/predicting_type_with_trained_decision_tree.py in get_xml_files(xml_file_folder)
#      29 def get_xml_files(xml_file_folder):
#      30   if len([file for file in os.listdir(xml_file_folder) if file.endswith('.xml')])==0:
# ---> 31     raise FileNotFoundError("No xml file was found! Please upload the file with the tokenized phrases.")
#      32   return [file for file in os.listdir(xml_file_folder) if file.endswith('.xml')]
#      33
#
# FileNotFoundError: No xml file was found! Please upload the file with the tokenized phrases.

# %%
os.environ["PUML_XML_DIR"] = "/content/puml_files/"
# %run /content/IC_codes/xml_to_plantuml.py
